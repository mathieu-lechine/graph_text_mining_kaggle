# %%
import csv

# %%
with open("training_set.txt", "r") as f:
    reader = csv.reader(f)
    training_set  = list(reader)

# %%
training_set[0]
# Out:
# ['9510123', '9502114', '1']

# %%
training_set = [element[0].split(" ") for element in training_set]

# %%
for l,line in enumerate(training_set) :
    for a,arc in enumerate(training_set) :
        if arc[1] == line[0] :
            if arc[0] == line[1] :
                print l,a
    if l%1000 == 0 : print l
# Out:
# 0
# 389 188339
# 1000
# 1743 569609
# 1747 61006
# 2000
# 3000
# 3021 461463
# 3256 104740
# 4000
# 4557 507701
# 5000
# 5231 130416
# 5494 402847
# 5725 351905
# 5849 368675
# 6000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c632938529e8> in <module>()
#       1 for l,line in enumerate(training_set) :
#       2     for a,arc in enumerate(training_set) :
# ----> 3         if arc[1] == line[0] :
#       4             if arc[0] == line[1] :
#       5                 print l,a
#
# KeyboardInterrupt:

# %%
for l,line in enumerate(training_set) :
    if l>6000 :
        for a,arc in enumerate(training_set) :
            if arc[1] == line[0] :
                if arc[0] == line[1] :
                    print l,a
                    print line
                    print arc
    if l%1000 == 0 : print l
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 6555 178199
# ['203013', '112128', '1']
# ['112128', '203013', '1']
# 6601 590127
# ['9612229', '9711020', '0']
# ['9711020', '9612229', '0']
# 7000
# 8000
# 8216 93497
# ['112013', '112205', '1']
# ['112205', '112013', '1']
# 8472 269220
# ['9911249', '9801193', '0']
# ['9801193', '9911249', '0']
# 8745 13094
# ['9912140', '9910092', '1']
# ['9910092', '9912140', '1']
# 9000
# 9444 371950
# ['9604007', '9606130', '1']
# ['9606130', '9604007', '1']
# 9452 218789
# ['204260', '202030', '1']
# ['202030', '204260', '1']
# 9646 124788
# ['9508115', '9912263', '0']
# ['9912263', '9508115', '0']
# 10000
# 10383 186401
# ['11048', '11073', '1']
# ['11073', '11048', '1']
# 11000
# 11171 440084
# ['208107', '208108', '1']
# ['208108', '208107', '1']
# 12000
# 12433 493995
# ['101145', '101102', '1']
# ['101102', '101145', '1']
# 13000
# 13094 8745
# ['9910092', '9912140', '1']
# ['9912140', '9910092', '1']
# 13102 550906
# ...
